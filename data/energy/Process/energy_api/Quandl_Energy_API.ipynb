# %%
import quandl

# %%
import configparser
config = configparser.ConfigParser()
config.read('../../../config.py')
API_Key = config['DEFAULT']['API_KEY']

# %%
quandl.ApiConfig.api_key = API_Key

# %%
data_df = quandl.get("EIA/PET_RWTC_D")

# %% [markdown]
# * Makes a Time Series Call
# * Gets the WTI Crude Oil Price with Quandl Code of EIA/PET_RWTC_D <br>
#  from the US Department of Energy Dataset

# %%
data_df
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87
# ...           ...
# 2020-10-28  37.27
# 2020-10-29  35.94
# 2020-10-30  35.64
# 2020-11-02  36.60
# 2020-11-03  37.44
#
# [8803 rows x 1 columns]

# %%
import pandas as pd

# %%
crude_oil_df = data_df.copy()
#WTI Crude Oil Per Barrel Price

# %%
crude_oil = crude_oil.rename(columns={"Date":"date", "Value":"usd_per_barrel"})
crude_oil = crude_oil.set_index("date")
#because the Table Was set up as:

# %%
display_n(crude_oil_df, 1)
# Out:
#             USD_per_Barrel
# Date
# 1986-01-02           25.56
# ...                    ...
# 2020-11-03           37.44
#
# [8803 rows x 1 columns]

# %%
crude_oil_df
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87
# ...           ...
# 2020-10-28  37.27
# 2020-10-29  35.94
# 2020-10-30  35.64
# 2020-11-02  36.60
# 2020-11-03  37.44
#
# [8803 rows x 1 columns]

# %%
#henry hubs natural gas data

# %%
crude_oil_df.to_csv(r'crude_oil.csv')

# %%
natural_gas_df = quandl.get("CHRIS/CME_NG12")
#Natural Gas (Henry Hub) Physical Futures, Continuous Contract #12 (NG12)

# %%
natural_gas_df
# Out:
#              Open   High    Low   Last  Change  Settle  Volume  \
# Date
# 1990-06-19  1.622  1.635  1.622  1.622     NaN   1.622    11.0
# 1990-06-20  1.590  1.590  1.590  1.590     NaN   1.590     0.0
# 1990-07-02  1.630  1.630  1.590  1.630     NaN   1.630     5.0
# 1990-07-03  1.640  1.640  1.640  1.640     NaN   1.640     0.0
# 1990-07-05  1.640  1.640  1.640  1.640     NaN   1.640     0.0
# ...           ...    ...    ...    ...     ...     ...     ...
# 2020-11-03  3.122  3.129  3.061  3.072  -0.064   3.076  7590.0
# 2020-11-04  3.072  3.084  3.056  3.066  -0.008   3.068  4330.0
# 2020-11-05  3.071  3.119  3.029  3.030  -0.027   3.041  5849.0
# 2020-11-06  3.037  3.058  2.988  2.991  -0.033   3.008  4826.0
# 2020-11-09  2.982  3.033  2.975  2.989  -0.017   2.991  4633.0
#
#             Previous Day Open Interest
# Date
# 1990-06-19                        11.0
# 1990-06-20                        11.0
# 1990-07-02                         5.0
# 1990-07-03                         5.0
# 1990-07-05                         5.0
# ...                                ...
# 2020-11-03                     34279.0
# 2020-11-04                     34620.0
# 2020-11-05                     34669.0
# 2020-11-06                     35883.0
# 2020-11-09                     36167.0
#
# [7474 rows x 8 columns]

# %%
natural_gas_df = natural_gas_df[['Settle']]

# %%
natural_gas_df
# Out:
#             Settle
# Date
# 1990-06-19   1.622
# 1990-06-20   1.590
# 1990-07-02   1.630
# 1990-07-03   1.640
# 1990-07-05   1.640
# ...            ...
# 2020-11-03   3.076
# 2020-11-04   3.068
# 2020-11-05   3.041
# 2020-11-06   3.008
# 2020-11-09   2.991
#
# [7474 rows x 1 columns]

# %%
natural_gas_df.to_csv(r'natural_gas.csv')
